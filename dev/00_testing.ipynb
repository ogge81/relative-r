# %%
import sys
sys.path.insert(0, "..")

from src.yfin.ticker import Ticker
from src.yfin.sector import Sector
from src.yfin.industry import Industry

from src.utils.files import get_ticker_symbol

tickers = get_ticker_symbol(min_volume=2000000)

print(len(tickers))
# Out:
# 96
